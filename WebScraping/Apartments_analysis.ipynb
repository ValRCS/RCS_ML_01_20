# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !dir *.xlsx
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5AA0-2A07
#
#  Directory of C:\Users\val-p1\Github\RCS_ML_01_20\WebScraping
#
# 02/01/2020  02:51 PM           277,342 apartments.xlsx
# 02/03/2020  07:17 PM           578,812 apartments_2_19_17_21.xlsx
# 02/03/2020  07:20 PM           274,123 apartments_2_19_20_11.xlsx
#                3 File(s)      1,130,277 bytes
#                0 Dir(s)  292,066,131,968 bytes free

# %%
df = pd.read_excel("apartments_2_19_20_11.xlsx")
df.head()
# Out:
#    Unnamed: 0                                                URL  \
# 0           0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1           1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2           2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3           3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4           4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena
# 0   1/5  P. kara  1,261 €   58,000  €
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# URL            object
# Description    object
# Iela           object
# Ist.           object
# m2             object
# Stāvs          object
# Sērija         object
# Cena, m2       object
# Cena           object
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0
# count  2689.000000
# mean   1344.000000
# std     776.391761
# min       0.000000
# 25%     672.000000
# 50%    1344.000000
# 75%    2016.000000
# max    2688.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'URL', 'Description', 'Iela', 'Ist.', 'm2', 'Stāvs',
#        'Sērija', 'Cena, m2', 'Cena'],
#       dtype='object')

# %%
badcolumn = df.columns[0]
badcolumn
# Out:
# 'Unnamed: 0'

# %%
# how to drop a column
df = df.drop([badcolumn], axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-dce25be5d886> in <module>
#       1 # how to drop a column
# ----> 2 df = df.drop([badcolumn], axis=1)
#       3 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena
# 0   1/5  P. kara  1,261 €   58,000  €
# 1   1/3  P. kara  1,753 €  135,000  €
# 2   4/4  P. kara    795 €   35,000  €
# ...

# %%
df[df['Ist.'] == 'Citi']['Ist.'] = 0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Ist.'].replace(regex=r'Citi*', value=0)
df[df['Ist.'] == 'Citi']['Ist.']
# Out:
# 16      Citi
# 291     Citi
# 342     Citi
# 518     Citi
# 554     Citi
# 563     Citi
# 692     Citi
# 766     Citi
# 2399    Citi
# 2439    Citi
# Name: Ist., dtype: object

# %%
df[df['Ist.'] == 'Citi']['Ist.']
# Out:
# Series([], Name: Ist., dtype: object)

# %%
df.loc[df['Ist.'] == 'Citi', ['Ist.']] = -1
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena
# 0   1/5  P. kara  1,261 €   58,000  €
# 1   1/3  P. kara  1,753 €  135,000  €
# 2   4/4  P. kara    795 €   35,000  €
# ...

# %%
df.loc[df['Ist.'] == '-', ['Ist.']] = 0
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena
# 0   1/5  P. kara  1,261 €   58,000  €
# 1   1/3  P. kara  1,753 €  135,000  €
# 2   4/4  P. kara    795 €   35,000  €
# ...

# %%
df["Rooms"] = df[['Ist.']].apply(pd.to_numeric, errors='coerce', axis=1)
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena  Rooms   Size
# 0   1/5  P. kara  1,261 €   58,000  €      3   46.0
# 1   1/3  P. kara  1,753 €  135,000  €      3   77.0
# ...

# %%
df['Size'] = df[['m2']].apply(pd.to_numeric, errors='coerce', axis=1)
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena  Rooms   Size
# 0   1/5  P. kara  1,261 €   58,000  €      3   46.0
# 1   1/3  P. kara  1,753 €  135,000  €      3   77.0
# ...

# %%
df[df["Ist."] == "Citi"]
# Out:
# Empty DataFrame
# Columns: [URL, Description, Iela, Ist., m2, Stāvs, Sērija, Cena, m2, Cena, Rooms, Size]
# Index: []

# %%
df.describe()
# Out:
#              Rooms         Size
# count  2689.000000  2687.000000
# mean      2.448122    65.909937
# std       1.063640    35.643997
# min      -1.000000     7.000000
# 25%       2.000000    44.000000
# 50%       2.000000    58.000000
# 75%       3.000000    78.000000
# max       6.000000   350.000000

# %%
indexNames = df[ df['Cena'] == 'pērku'].index
indexNames
# Out:
# Int64Index([], dtype='int64')

# %%
df['Price'] = df['Cena'].apply(lambda el: int(el.split(" ")[0].replace(',','')))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-5d0f7d313d75> in <module>
# ----> 1 df['Price'] = df['Cena'].apply(lambda el: int(el.split(" ")[0].replace(',','')))
#       2 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-37-5d0f7d313d75> in <lambda>(el)
# ----> 1 df['Price'] = df['Cena'].apply(lambda el: int(el.split(" ")[0].replace(',','')))
#       2 df.head()
#
# ValueError: invalid literal for int() with base 10: 'pērku'

# %%
def cleanDF(df):
    # for each price element, i split by empty space, get begging, get rid of comma, then cast to int
    df[['Stāvi', 'm2']] = df[['Stāvi', 'm2']].apply(pd.to_numeric, errors='coerce', axis=1)
    df['Price'] = df['Cena'].apply(lambda el: int(el.split(" ")[0].replace(',','')))
    # bonus, create currency column
    df['Currency'] = df['Cena'].apply(lambda el: el.split(" ")[-1])
    return df

# %%
.str.extract(r'(\d+),(\d+)', expand=True)
s.head()

# %%
s = df['Cena'].apply(lambda x: x.replace(',',''))
s.head()
# Out:
# 0     58000  €
# 1    135000  €
# 2     35000  €
# 3    190000  €
# 4     99000  €
# Name: Cena, dtype: object

# %%
price = s.str.extract(r'(\d+)')
price.head()
# Out:
#         0
# 0   58000
# 1  135000
# 2   35000
# 3  190000
# 4   99000

# %%
len(df)
# Out:
# 2689

# %%
len(price)
# Out:
# 2689

# %%
df['Price'] = price
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena  Rooms   Size   Price
# 0   1/5  P. kara  1,261 €   58,000  €      3   46.0   58000
# ...

# %%
df.Price = df.Price.astype('float64')
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena  Rooms   Size     Price
# 0   1/5  P. kara  1,261 €   58,000  €      3   46.0   58000.0
# ...

# %%
df["Price/m2"] = df['Price'] / df['Size']
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena  Rooms   Size     Price     Price/m2
# 0   1/5  P. kara  1,261 €   58,000  €      3   46.0   58000.0  1260.869565
# ...

# %%
df.iloc[0:5]['URL']
# Out:
# 0    https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1    https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2    https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3    https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4    https://www.ss.com/msg/lv/real-estate/flats/ri...
# Name: URL, dtype: object

# %%
df["Region"] = df['URL'].apply(lambda el: el.split("/")[-2])
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 1  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 2  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 3  https://www.ss.com/msg/lv/real-estate/flats/ri...
# 4  https://www.ss.com/msg/lv/real-estate/flats/ri...
#
#                                          Description           Iela Ist.   m2  \
# 0  Renovated 3-room apartment with an overall are...  Valdemāra 121    3   46
# 1  Cena atbilst īpašuma novērtējuma summai. Pilnī...  Strēlnieku 19    3   77
# 2  Divistabu dzīvoklis ar zemi īpašumā. Dzīvoklis...  Bruņinieku 78    2   44
# 3  Divi dzīvokļi, tikko pēc remonta. Tiek pārdoti...      Barona 29    3  107
# 4  Pārdod ļoti skaistu 3 istabu (76m2) dzīvokli a...    Tallinas 23    3   76
#
#   Stāvs   Sērija Cena, m2        Cena  Rooms   Size     Price     Price/m2  \
# 0   1/5  P. kara  1,261 €   58,000  €      3   46.0   58000.0  1260.869565
# ...

# %%
df.describe()
# Out:
#              Rooms         Size          Price     Price/m2
# count  2689.000000  2687.000000    2685.000000  2685.000000
# mean      2.448122    65.909937   90181.036127  1294.760305
# std       1.063640    35.643997   73400.979021   584.719610
# min      -1.000000     7.000000     250.000000     7.812500
# 25%       2.000000    44.000000   43000.000000   906.976744
# 50%       2.000000    58.000000   65000.000000  1137.254902
# 75%       3.000000    78.000000  118000.000000  1593.750000
# max       6.000000   350.000000  650000.000000  4646.792453

# %%
typedf = df.groupby(['Region', 'Sērija'])
typedf.describe()
# Out:
#                        Rooms                                                 \
#                        count      mean       std  min   25%  50%   75%  max
# Region        Sērija
# agenskalns    103.       3.0  2.333333  1.154701  1.0  2.00  3.0  3.00  3.0
#               467.       2.0  1.500000  0.707107  1.0  1.25  1.5  1.75  2.0
#               602.       1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0
#               Hrušč.    16.0  1.875000  0.718795  1.0  1.00  2.0  2.00  3.0
#               Jaun.     24.0  2.750000  0.737210  2.0  2.00  3.0  3.00  4.0
#               LT proj.   3.0  2.666667  0.577350  2.0  2.50  3.0  3.00  3.0
#               P. kara   32.0  2.093750  1.399525 -1.0  1.00  2.0  2.25  6.0
#               Renov.    34.0  2.647059  0.949716  1.0  2.00  2.0  3.75  4.0
#               Specpr.   12.0  2.166667  0.717741  1.0  2.00  2.0  3.00  3.0
#               Staļina    6.0  2.500000  0.836660  2.0  2.00  2.0  2.75  4.0
# ...

# %%
typedf.describe().to_excel("apartments_by_type.xlsx")

# %%
rdf = df.groupby(['Region'])
rdf.describe()
# Out:
#                          Rooms                                                 \
#                          count      mean       std  min   25%  50%   75%  max
# Region
# agenskalns               133.0  2.360902  1.024979 -1.0  2.00  2.0  3.00  6.0
# aplokciems                13.0  2.384615  1.043908  1.0  2.00  2.0  3.00  4.0
# beberbeki                  1.0  0.000000       NaN  0.0  0.00  0.0  0.00  0.0
# bergi                      7.0  2.428571  0.975900  1.0  2.00  2.0  3.00  4.0
# bierini                    6.0  2.500000  1.048809  1.0  2.00  2.5  3.00  4.0
# bolderaya                 33.0  2.030303  0.769937  1.0  2.00  2.0  2.00  4.0
# breksi                     3.0  2.666667  0.577350  2.0  2.50  3.0  3.00  3.0
# bukulti                    2.0  3.500000  0.707107  3.0  3.25  3.5  3.75  4.0
# bulli                      1.0  4.000000       NaN  4.0  4.00  4.0  4.00  4.0
# centre                   754.0  2.714854  1.255899 -1.0  2.00  3.0  3.00  6.0
# ...

# %%
rdf.describe().to_excel("region_pricing.xlsx")

# %%
sdf = rdf.describe()[("Price/m2")]
sdf
# Out:
#                          count         mean          std          min  \
# Region
# agenskalns               133.0  1242.572719   464.836669   338.235294
# aplokciems                13.0  1371.224983   284.869541   638.297872
# beberbeki                  0.0          NaN          NaN          NaN
# bergi                      7.0  1052.433778   333.596419   564.285714
# bierini                    6.0  1410.510229   157.451227  1250.000000
# bolderaya                 33.0   705.342551   175.824414   273.437500
# breksi                     3.0   943.253968   479.302801   651.515152
# bukulti                    2.0  1339.206295   112.730674  1259.493671
# bulli                      1.0   616.352201          NaN   616.352201
# centre                   754.0  1717.690402   642.091397   119.754491
# chiekurkalns              29.0  1166.911740   460.807879   282.916667
# darzciems                 36.0   936.986031   278.807542   315.789474
# ...

# %%
type(sdf)
# Out:
# pandas.core.frame.DataFrame

# %%
sdf.sort_values(by='mean', ascending=False)
# Out:
#                          count         mean          std          min  \
# Region
# kipsala                   17.0  2829.550527   559.866466  1736.956522
# other                      2.0  2463.751438  1170.103051  1636.363636
# vecriga                   69.0  2227.770236   482.206144  1401.574803
# kliversala                 8.0  1740.427652   691.303323   986.842105
# centre                   754.0  1717.690402   642.091397   119.754491
# grizinkalns               18.0  1663.347078   531.936627   640.000000
# mezhapark                 27.0  1559.148836   582.155172   799.714286
# bierini                    6.0  1410.510229   157.451227  1250.000000
# aplokciems                13.0  1371.224983   284.869541   638.297872
# kleisti                    3.0  1355.698296   125.068966  1247.524752
# bukulti                    2.0  1339.206295   112.730674  1259.493671
# dreilini                   2.0  1339.147287   243.924432  1166.666667
# ...
